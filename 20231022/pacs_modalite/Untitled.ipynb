# %%
import pandas as pd

df = pd.read_csv('assets-2021-11-25T15_16_40+01_00.csv')

# print(df.to_string()) 
# print(df) 
# df.info()
# mask=df["IP"]=="10.208.37.49"
# df[mask]
df[df["IP"].str.contains("10.120.2")]
# Out:
#        Risk  CMDX Score       Category                   Type    Vendor  \
# 8127   None           0  User Endpoint  Generic User Endpoint  TexasIns
# 15345  None           0            IoT       Video Conference  Viavideo
#
#                      MAC          IP Available Actions  Actions In Progress  \
# 8127   84:7E:40:2D:8B:04  10.120.2.5               NaN                  NaN
# 15345  00:E0:DB:45:3E:E0  10.120.2.4               NaN                  NaN
#
#        Network Mitigation  ...      Location Connection Type  \
# 8127                  NaN  ...           NaN             NaN
# 15345                 NaN  ...  snmplocation       Wired LAN
#
#       Connected to SSID Department Last Scan Time  Average Daily Active Hours  \
# 8127                NaN        NaN            NaN                         NaN
# 15345               NaN        NaN            NaN                         NaN
#
#       Average Daily Dicom Studies   MDS2 Last Vendor Access  \
# ...
